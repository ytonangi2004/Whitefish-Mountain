# %%
### (Whitefish mountain Ratio_of total_chairs_To_Other ScatterPlot
### (WFM_total_chairs_To_Other Ratio ScatterPlot
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("ski_data_with_ratios.csv")
x = df["total_chairs"]
y = df["ratio_of_total_chairs_other_to_WFM"]
plt.xlabel('Total Chairs') 
plt.ylabel('Ratio Total Chairs Other to WFM ') 
plt.title('Total Chairs Value of Whitefish Mountain Resort')

plt.scatter(x, y)
plt.show() 
### print(df["WFM_total_chairs_To_Other"])
